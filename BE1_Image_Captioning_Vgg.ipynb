# %% [markdown]
# <h1>MSO 3.4 - Apprentissage automatique</h1>
#
# <h2>BE1 - Image captioning</h2>

# %%
from google.colab import files

# %%
# !zip -r /content/file.zip /content/
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   adding: content/Flicker8k_Dataset/3493255026_5fdaa52cbe.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2114355355_9d7e2d8178.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2286032269_8ba929709c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3514179514_cbc3371b92.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/386656845_4e77c3e3da.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/778885185_3f6905370b.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3209966887_5b744bd050.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3126681108_f88128699c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2420696992_22e0dd467d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3096918227_f9d26a7db2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/468911753_cc595f5da0.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2886533440_dfa832f2fa.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/822836318_21544f0f78.jpg (deflated 2%)
#   adding: content/Flicker8k_Dataset/975131015_9acd25db9c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3295671644_0e10891b6d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2364774105_fbaf0c191f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3076052114_233f42ae5b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3711030008_3872d0b03f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3477715432_79d82487bb.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2908512223_7e27631ed4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3487378989_c051d2715b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3432656291_a6c7981f6e.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/946051430_8db7e4ce09.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/238512430_30dc12b683.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3431194126_ca78f5fde6.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3616638478_641d02183d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2875528143_94d9480fdd.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2272750492_91e8f67328.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3217056901_fe2c70377d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3253060519_55d98c208f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/434792818_56375e203f.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2599903773_0f724d8f63.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1468429623_f001988691.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2580215443_4e64afe3d5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3357937209_cf4a9512ac.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2965604928_435dc93bf7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2090997177_76d482b158.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3562470436_6e193643ce.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2073105823_6dacade004.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2706766641_a9df81969d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2358898017_24496b80e8.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3474265683_43b1033d94.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1584315962_5b0b45d02d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3673032164_6c6843de87.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3212465975_b657f40eed.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/195962284_e57178054a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/111766423_4522d36e56.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3399798295_a452963365.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3278189732_f750cb26b7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2095078658_c14ba89bc2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3003011417_79b49ff384.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3484820303_7be0e914b4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/466176275_f40d37851e.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/746787916_ceb103069f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3422146099_35ffc8680e.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2921094201_2ed70a7963.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1075716537_62105738b4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/61209225_8512e1dad5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1721637099_93e9ec2a2f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/859620561_de417cac1e.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1211015912_9f3ee3a995.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/576920249_df1bdc2068.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3359587274_4a2b140b84.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/1343426964_cde3fb54e8.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3326249355_e7a7c71f06.jpg (deflated 9%)
#   adding: content/Flicker8k_Dataset/3376972502_35e3e119cd.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3313232606_4ce7e16b87.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3500342526_393c739e2f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3679707139_1cc1e71237.jpg (deflated 14%)
#   adding: content/Flicker8k_Dataset/2252299132_14ca6e584b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2840344516_8e15fe2668.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/494907021_321e82877a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2587818583_4aa8e7b174.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2720215226_5a98ff2bd3.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3091382602_60b9b53ed1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3367851138_757d6bd2ef.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/432167214_c17fcc1a2d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2603125422_659391f961.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/496110746_a93ca191ae.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3596131692_91b8a05606.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3672940355_47f30e2b28.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3091338773_9cf10467b4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/155221027_b23a4331b7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/217838128_1f0a84ddc1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3613955682_3860e116cf.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3591170729_406fdb74e5.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2136514643_93d8f75a77.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2896668718_0c3cff910f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2569643552_23696a9ba5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1387461595_2fe6925f73.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2695001634_127fe2f0d7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2650568697_ffb79bf2ea.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3559425864_0462d7613f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3210457502_c6030ce567.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2981702521_2459f2c1c4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1222322358_225067636e.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/127490019_7c5c08cb11.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2748729903_3c7c920c4d.jpg (deflated 2%)
#   adding: content/Flicker8k_Dataset/210126070_0d43b300b9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3259579174_30a8a27058.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2099323664_bb20457f26.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2975118353_5af5a5df54.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3570800810_978c993133.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/242064301_a9d12f1754.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3550459890_161f436c8d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/393987665_91d28f0ed0.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3757598567_739b7da835.jpg (deflated 16%)
#   adding: content/Flicker8k_Dataset/3512791890_eb065b460a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3351586010_7ffaa90ea8.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/424379231_23f1ade134.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2298097636_c5de0079de.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/759015118_4bd3617e60.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2140747429_62cfd89ae9.jpg (deflated 2%)
#   adding: content/Flicker8k_Dataset/2987096101_a41896187a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2648310638_d6c576b5e4.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2874728371_ccd6db87f3.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3515904775_f8acc5909e.jpg (deflated 22%)
#   adding: content/Flicker8k_Dataset/2930622766_fa8f84deb1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2867937005_91c092b157.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2403544744_cba152f5c1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3547647914_4dd56a8c1b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3708172446_4034ddc5f6.jpg (deflated 9%)
#   adding: content/Flicker8k_Dataset/2836703077_fa9c736203.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2393410666_b8c20fff61.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3139389284_f01bd4c236.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3474330484_a01d8af624.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3427540832_c882fded1d.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2657643451_b9ddb0b58f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3164423279_9b27cb6a06.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3222842866_cb85243ce4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2689491604_d8760f57b4.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/189721896_1ffe76d89e.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3212085754_35fdc9ccaa.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2273871383_1ddb3562ea.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2548777800_d7b9cf1c2b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2887750774_920eb171aa.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3084011028_d1e2c40d7d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/554526471_a31f8b74ef.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1295698260_e10c53c137.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/587604325_af5d6df679.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2953861572_d654d9b6f2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2101128963_fdf8b2a0d7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3046916429_8e2570b613.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2901074943_041aba4607.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3455898176_f0e003ce58.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2466495935_623b144183.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1131340021_83f46b150a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3036596725_541bbe0955.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/486720042_b785e7f88c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/300765528_8c8f709dda.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1470132731_fa416b7504.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/535399240_0714a6e950.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/384465370_9918873f9a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1332208215_fa824f6659.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/735787579_617b047319.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/160792599_6a7ec52516.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3207654194_43d6bebd68.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3045613316_4e88862836.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2319197581_94f807b204.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/502115726_927dd684d3.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1787222774_d5c68cce53.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/245252561_4f20f1c89e.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3532192208_64b069d05d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3694219419_a7a83d4886.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/444872454_9f51e07f88.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3042483842_beb23828b9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2449289139_08fc1092c1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2656749876_e32495bd8c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2920969723_83918fe909.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3222041930_f642f49d28.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2854959952_3991a385ab.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/771366843_a66304161b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3426933951_2302a941d8.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2858759108_6e697c5f3e.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1470061031_4cb59c12a8.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/241345770_9f8aa6723c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3178005751_fca19815ac.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3198247669_7493af04a7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3279228339_71deaa3d9b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1874617189_e85d3f4326.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2830869109_c4e403eae6.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/393958545_48c17c66d1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3640104986_5d8c9a9948.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3461106572_920c8c0112.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3569755200_cef7ee2233.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/820169182_f5e78d7d19.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2288315705_5f4c37d932.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2557129157_074a5a3128.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2251418114_2b0cd4c139.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2295216243_0712928988.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2818735880_68b3dfe1f5.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2755314937_1e974bf2b5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2562347802_c049a2ba88.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3132006797_04822b5866.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2785108434_cd4a1c949c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/393284934_d38e1cd6fe.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2192411521_9c7e488c5e.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3141440149_00becbbb93.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2752809449_632cd991b3.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2976537455_f3988c2d46.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3533775651_9d7e93dacf.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3235076435_1eaa40bd0a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3558683579_8fb36b55a6.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/525968880_82623392d1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2315807231_6948b3f3a5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3634828052_3b6aeda7d6.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3608400551_d6f7965308.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3504275465_604ce2ef34.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1401961581_76921a75c5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2292406847_f366350600.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1155138244_859fd6e079.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3448490813_f9623e864d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3692593096_fbaea67476.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/375384566_254c2362d4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2537119659_fa01dd5de5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2447284966_d6bbdb4b6e.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2987775031_3f9ac69319.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3092756650_557c5f2d03.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1295671216_cde1b9c9d1.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3214579977_fa9fb006a6.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2587106431_1cc0e719c6.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3172369593_eb4d787ffb.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2887744223_029f2fd5fe.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/632251903_b36701a5e9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/124972799_de706b6d0b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1206506157_c7956accd5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2293149170_38fb2257ea.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2991375936_bf4b0a7dc0.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/241346434_0527ea1c07.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3462396164_ba9849c14b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3517362674_0f5296de19.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3344632789_af90d54746.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3191027142_33e86636ca.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3516653997_98ec551a67.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1298866571_b4c496b71c.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3587449716_3bf1552c36.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3410902181_b2a3c6eec9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/470373679_98dceb19e7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/241345533_99c731403a.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3508882611_3947c0dbf5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/464251704_b0f0c4c87a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/181777261_84c48b31cb.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3006094603_c5b32d2758.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/241345522_c3c266a02a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3722572342_6904d11d52.jpg (deflated 6%)
#   adding: content/Flicker8k_Dataset/2712974062_6d5b6aa7f0.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3744832122_2f4febdff6.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3244910944_612b8ce98f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2805822564_6dee48e506.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/1177994172_10d143cb8d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1932314876_9cc46fd054.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2561849813_ff9caa52ac.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2136992638_098d62a3c5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3419238351_ac18b440c0.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3355494822_61353a224d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2935649082_1ca60180c6.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/397286183_745abbf40d.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2928835996_88b9f9503d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3628059004_5c3529b120.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3201594926_cd2009eb13.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3275711232_e261143664.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2560388887_55abc9083d.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2087317114_cf06df5aa5.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/572618443_647483ca82.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3203878596_cbb307ce3b.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3605061440_1d08c80a57.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3692892751_f6574e2700.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3262760716_1e9734f5ba.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/146098876_0d99d7fb98.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/457875937_982588d918.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3569979711_6507841268.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2303016989_0deb96c8d9.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3004291093_35d6fd8548.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2884420269_225d27f242.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3108378861_d2214d971e.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3290465391_258429e2f9.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/1397887419_e798697b93.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2335619125_2e2034f2c3.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2990471798_73c50c76fb.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/33108590_d685bfe51c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3626964430_cb5c7e5acc.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2911919938_6bb6587a36.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3411393875_a9ff73c67a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3717309680_e5105afa6d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2089539651_9e518ec7de.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2382411771_a16145f345.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/505062117_a70b4e10ab.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3339105374_cc41e0b7d7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3601843201_4809e66909.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3513265399_a32e8cfd18.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1332815795_8eea44375e.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/290019324_23582048d4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/396360611_941e5849a3.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/236095031_5cb17dc54a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/109823394_83fcb735e1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/226607225_44d696db6b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3211581957_df2f7e2236.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3280052365_c4644bf0a5.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3176131893_7181c733aa.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3647693147_0d0434351b.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3185662156_c877583c53.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2934573544_7ffe92a2c9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/362316425_bda238b4de.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3626642428_3396568c3c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2771424045_1fdf9617eb.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/404890608_33f138aefa.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3126773489_7ae425af17.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3259229498_2b5708c0c6.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3480379024_545e8ec818.jpg (deflated 4%)
#   adding: content/Flicker8k_Dataset/140430106_2978fda105.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3478176372_7c510a0cef.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2245348304_08bc5642f1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3594566537_55bd712fdb.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3665569615_9a71c4b6e4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3517023411_a8fbd15230.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2993049054_611f900644.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2635400219_2e1a984fd3.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/521186251_e97d1f50f8.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1419286010_b59af3962a.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3113682377_14fc7b62b0.jpg (deflated 2%)
#   adding: content/Flicker8k_Dataset/2950905787_f2017d3e49.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3308488725_f91d9aba27.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3123351642_3794f2f601.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2970461648_fe14ba0359.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1511807116_41c3645e8c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/166433861_70b66cd381.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3389448506_7025e7cc12.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/207930963_af3a2f1784.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3658016590_f761e72dc3.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/58363928_6f7074608c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/352382023_7605223d1c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1402641725_5e027ecaa7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3694064560_467683205b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2327240505_e73cc73246.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3264650118_be7df266e7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3616808182_fb4eaec778.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2285570521_05015cbf4b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2816259113_461f8dedb0.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3219065971_702c4e8c34.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3284955091_59317073f0.jpg (deflated 5%)
#   adding: content/Flicker8k_Dataset/3366571152_20afb88ac1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3359530430_249f51972c.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3273403495_fcd09c453e.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3394586927_eae7732b64.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2363419943_717e6b119d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3434526008_02359881a0.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3383491811_fd9d3a891d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/977856234_0d9caee7b2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2268596214_ca532f5c63.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3606355203_1260f43ec0.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/278002947_3fd22a2cb6.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2119660490_ce0d4d1f73.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2909609550_070eea49b5.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3236677456_75821e3583.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3429465163_fb8ac7ce7f.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/483136916_16976f4902.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/84713990_d3f3cef78b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3227111573_c82f7d68b1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2700147489_f1664f2b61.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3394070357_cb2a3243fc.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2500567791_101d5ddee3.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3478877323_0a507a601b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2258951972_92763fddab.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/708860480_1a956ae0f7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1801063894_60bce29e19.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1439046601_cf110a75a7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3562903245_85071bb5f9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3628017876_4ac27e687b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/179009558_69be522c63.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3301935788_2bb7bbc515.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3131632154_098f86f4cb.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2863848437_f2592ab42d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3557324238_6ba58831d9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2067833088_04e84e5bf2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1388346434_524d0b6dfa.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3085667865_fa001816be.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3163273640_8d3ef22eaf.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2286235203_af3cd8f243.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/410422753_de506155fa.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2423292784_166ee54e0b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2780031669_a0345cfc26.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/792362827_5ab5281b99.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1418019748_51c7d59c11.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/436013859_793d870b6f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1818403842_553a2a392c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1598085252_f3219b6140.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3716277216_c04002be81.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3015368588_ef0a06076d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/272156850_c4445a53f4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2744705147_acd767d3eb.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2171576939_d1e72daab2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3458434150_2b0d619244.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3447007090_08d997833a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3472540184_b0420b921a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2711720095_0b98426d3c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2766291711_4e13a2b594.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3422219732_3d0be52cc3.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2090386465_b6ebb7df2c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3560891822_7d4c1e3580.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3536561454_e75993d903.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/309238565_2d5d8dc8bf.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1439282131_3814d6ae04.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2531837969_6f28637811.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2593695271_4d9cc9bd6f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3514184232_b336414040.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2977379863_2e8d7a104e.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2387197355_237f6f41ee.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2833582518_074bef3ed6.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/514036362_5f2b9b7314.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2982881046_45765ced2c.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3133825703_359a0c414d.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2939197393_93dc64c4bb.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3046190891_05c6ecd9b6.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/1523984678_edd68464da.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2786245676_0a69543832.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3646970605_d25c25340b.jpg (deflated 2%)
#   adding: content/Flicker8k_Dataset/121971540_0a986ee176.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/377872672_d499aae449.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1394599090_fe0ba238f0.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3572942419_16ebdc3d46.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2100046085_69b59b6645.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3251648670_9339943ba2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3460458114_35037d4d4c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2987121689_f9de6c479b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2260649048_ae45d17e68.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3107059919_0594269f72.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3301021288_95935b7a74.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/108899015_bf36131a57.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2446601467_a35841cb1d.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3544483327_830349e7bc.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3497485793_e36c1d2779.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3039214579_43ef79f931.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2559921948_06af25d566.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/624058168_f1c5e87e59.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3514188115_f51932ae5d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3501781809_88429e3b83.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3049770416_0fb1954315.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/544257613_d9a1fea3f7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3183060123_ea3af6278b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2913972180_547783dd3d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2836325261_a3bf5c59be.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3396153660_f729d9f9b9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1663454406_5e2cf8c5bb.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3397310901_cbef5c06ef.jpg (deflated 2%)
#   adding: content/Flicker8k_Dataset/3077166963_fe172c709d.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/405253184_5f611f3880.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/848180689_d67a1361ce.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/255741044_1102982213.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2612488996_9450de0e54.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3697153626_90fb177731.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3018467501_a03d404413.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3239021459_a6b71bb400.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2949353587_64c54e9589.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3539767254_c598b8e6c7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2586911841_41b7a48c91.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2973269132_252bfd0160.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/421706022_1ddb6a7a78.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2911552402_5166bc173b.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2695961935_a2a6338f26.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2447289477_e888df561d.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2619267133_53a5904ef4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1459250022_bf1eddad11.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2837640996_0183db8d93.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2444339090_bf7b3211f4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/96985174_31d4c6f06d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/244760289_f4467b2b67.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3497106366_d1a256e723.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/510791586_3913ade6a7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3210705660_2b14b7fb36.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3295391572_cbfde03a10.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/950411653_20d0335946.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/524036004_6747cf909b.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2602083686_e8a1af69cf.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3069216757_c419b3898e.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3425756814_13909354d4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/518610439_b64ab21c02.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3367053761_8ec5834bf3.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3301854980_233cc2f896.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2174206711_11cb712a8d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3697003897_d8ac13be9a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3409947123_a8d07edecf.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2298283771_fb21a4217e.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1773928579_5664a810dc.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/270263570_3160f360d3.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/519754987_51861fea85.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2465441099_a1761a1757.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2252264255_03fefc25af.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3426964258_67a0cee201.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/505955292_026f1489f2.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3170551725_1276644eab.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2848266893_9693c66275.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/278002875_d011ae9dc5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3512033659_7e8a0c2ffa.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3128164023_ebe8da4c32.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3616771728_2c16bf8d85.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/1488937076_5baa73fc2a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/717673249_ac998cfbe6.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2549968784_39bfbe44f9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2714220101_c31db50b10.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/261490838_2f3ac98b12.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2102315758_a9148a842f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3429391520_930b153f94.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3229442620_fd47d01b59.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3701509233_a2275a4e57.jpg (deflated 7%)
#   adding: content/Flicker8k_Dataset/3563461991_de05537878.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2348491126_30db0d46ef.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3122497129_d08f5729b8.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3462454965_a481809cea.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3099923914_fd450f6d51.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/327997381_55f90dc834.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/172092464_d9eb4f4f2f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1295669416_21cabf594d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/519228867_2fd25e38d4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2533414541_362bf043bb.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/439916996_1ddb9dc8e7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3216085740_699c2ce1ae.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/241346508_0b3907a95b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/444057017_f1e0fcaef7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1413956047_c826f90c8b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2890075175_4bd32b201a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2863349041_5eba6e3e21.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/236730743_0d4fd8de5a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1459032057_97e73ed6ab.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/448590900_db83c42006.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2765029348_667111fc30.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1053804096_ad278b25f1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2641770481_c98465ff35.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2988244398_5da7012fce.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2439384468_58934deab6.jpg (deflated 5%)
#   adding: content/Flicker8k_Dataset/2300229745_af7a20c959.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1417882092_c94c251eb3.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1499495021_d295ce577c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/131632409_4de0d4e710.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2944836001_b38b516286.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2676184321_858eff416b.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2790909995_8b7a03d9d1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/411011549_1298d2b4d2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2893374123_087f98d58a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/318667317_108c402140.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/255266148_7ba7df1a88.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2130851544_d36f4f2ea6.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1423997242_ea2189ec5e.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/452419961_6d42ab7000.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2528521798_fb689eba8d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2993388841_6746140656.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3535056297_e16f014cb7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/495014499_8fd065cfd9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/470887791_86d5a08a38.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3295418287_5d590dac43.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3247423890_163f00a2cb.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3533145793_5d69f72e41.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3094568845_d0b56c5651.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3165826902_6bf9c4bdb2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2538477523_1da77eb11c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2354829523_9542fc74ba.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/795081510_53fd17d101.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2249141510_f534708374.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3454754632_977c1523be.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1800601130_1c0f248d12.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3443030942_f409586258.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3636247381_65ccf8f106.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1662261486_db967930de.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2546667441_bbe87a6285.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/386470686_1ae9242878.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3282925526_535ff9f2b2.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3618504267_d7eaa495d0.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3319338707_892ae2a660.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/241347460_81d5d62bf6.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3697378565_7060d9281a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/429205889_ff5a006311.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2891961886_b7a2f0b0fd.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2918769188_565dd48060.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/44129946_9eeb385d77.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2680619645_ab6645218d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3456251289_c4ae31d817.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3215117062_6e07a86352.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3128856481_86e5df4160.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/535309053_ec737abde8.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1193116658_c0161c35b5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2346772831_b2748ba1f0.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/111497985_38e9f88856.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3498354674_b636c7992f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3677954655_df4c0845aa.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/350176185_b8c5591e36.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/118187095_d422383c81.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3615730936_23457575e9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2197275664_fabcf3424b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/506738508_327efdf9c3.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2218519240_cac5aab53c.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3106026005_473a7b1c8c.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/236518934_c62a133077.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2434074318_e35a567220.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/215214751_e913b6ff09.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3556792157_d09d42bef7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3240090389_97a8c5d386.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/514431934_9cf78f05a9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2652155912_8ba5426790.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3339263085_6db9fd0981.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/488089932_c3a5fa4140.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2891185857_54942809cf.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1685990174_09c4fb7df8.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/69710415_5c2bfb1058.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3036033157_522a43a550.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2485467050_1d5e2696d4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/504385521_6e668691a3.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2461372011_ebbf513766.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2407091303_931c918490.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3576259024_9c05b163aa.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/160541986_d5be2ab4c1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1077931201_1e0bb83105.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3188036349_8e4e2d6ca8.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3176277818_235486a3cd.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2396746868_0727e06983.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3435035138_af32890a4c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/870710405_51e507b31a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3220126881_b0a4f7cccb.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3405759441_fb31c80240.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2271955077_0020b4ee0d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/535123126_c06c1ab9bf.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1357724865_4faf4e1418.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1247181182_35cabd76f3.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2695085632_10c4e6ea78.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3293753378_7a8ddb98b2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3590647207_2d4ec3f52c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/537225246_dd0e2158a7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3490044563_8eb551ef59.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/191592626_477ef5e026.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2009636597_e3f4fe19fb.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2538423833_d1f492d1fb.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3475005101_6f6e437459.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3154152744_4e93ec8a62.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2064792226_97e41d8167.jpg (deflated 0%)
# ...
#   adding: content/Flicker8k_Dataset/1055623002_8195a43714.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3701291852_373ea46bb6.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3148647065_2d6cd88cf6.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3062273350_fd66106f21.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1659396176_ced00a549f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3288174272_2daa06d360.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1178705300_c224d9a4f1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3583293892_c96af8cd98.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2182050469_1edac0bc60.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2159447283_fab8c272b0.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3466353172_deb128bbb0.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3625519177_4c2bb9e7f0.jpg (deflated 5%)
#   adding: content/Flicker8k_Dataset/1570723692_3a2b064d43.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3341961913_9a9b362f15.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2482629385_f370b290d1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2384550175_e421d3a871.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2869765795_21a398cb24.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3523819210_99782628fc.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2043520315_4a2c782c90.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3320356356_1497e53f80.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1527333441_af65636a74.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/460350019_af60511a3b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2620113705_a8fa89b8f6.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2899089320_3e7f6bbaca.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/42637986_135a9786a6.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1282392036_5a0328eb86.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2212472643_80238475b5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1273001772_1585562051.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2213113526_beeb4f9bdc.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/241347700_ef2451d256.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3571147934_d1c8af1d6e.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/640053014_549d2f23d2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2056930414_d2b0f1395a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2649705487_4605e879e9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1119418776_58e4b93eac.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/444481722_690d0cadcf.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2600386812_8790879d9a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2710416789_555180e399.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/501684722_0f20c4e704.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2561295656_4f21fba209.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/417577408_eb571658c1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1342766791_1e72f92455.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3361990489_92244a58ef.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3604314527_5077cd9d43.jpg (deflated 3%)
#   adding: content/Flicker8k_Dataset/2330843604_b8d75d6ac7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3726590391_bc6e729bb6.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2074244690_82e30ff44b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2214132302_80064fd79d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3621652774_fd9634bd5b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3263946591_a1558b77d3.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3278777548_290b881018.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3310551665_15b79ef4ea.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1461667284_041c8a2475.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3542341321_faa2d2d48a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2715337869_e4fe36db50.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3373544964_c9f1253b7d.jpg (deflated 2%)
#   adding: content/Flicker8k_Dataset/2058124718_89822bc96e.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2437266971_b91a8f9a00.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3429581486_4556471d1a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2890057168_c712f932e0.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2554570943_122da6438f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/455856615_f6361d9253.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/1688699579_2f72328c7e.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2165461920_1a4144eb2b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2532294586_4cd76a837d.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/531152619_6db02a7ed9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/825918657_d92f1761f4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3068407619_5207b26986.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3426966595_c8c4e1e872.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3628698119_5566769777.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2666078276_f7b3056997.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2138487671_5b89104043.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/495054019_3dee8a02f5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3677860841_3aa9d8036c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/190965502_0b9ed331d9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2971211296_2587c3924d.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3181322965_ce9da15271.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3182405529_7692256746.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1432179046_8e3d75cf81.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/224702242_a62aaa6dff.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2553550034_5901aa9d6c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/590445887_4d4fa43923.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3225226381_9fe306fb9e.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/246901891_4c4ea49c3a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3671935691_57bdd0e778.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3326024473_4c16e4fbfc.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3604391853_b4809fcb8c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3159569570_dff24e7be9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/989851184_9ef368e520.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/341430859_4519802e8f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2694178830_116be6a6a9.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2930318834_8366811283.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1001773457_577c3a7d70.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1412832223_99e8b4701a.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3453313865_1ebff5393c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3477712686_8428614c75.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2942798367_022df04b49.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3219122000_bd6b4ae5ff.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/439049388_3dcee2d30b.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/537532165_e4b7c0e61a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/162152393_52ecd33fc5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1814391289_83a1eb71d3.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2905948395_ca3e6b3c9a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2602415701_7674eb19e4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3654103642_075f8af4f4.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3211199368_ca78387f72.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2972929655_04233b5489.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3171188674_717eee0183.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3523471597_87e0bf3b21.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2370221025_be4d9a4431.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3547524138_4157f660b0.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3337332770_5eda5cceb7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2157003092_eaeb977789.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2074146683_7c83167aa1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3595398879_13e33b8916.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2781296531_f6f0f6c0f5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3122579598_14841c038a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/462288558_b31a8a976f.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/315125146_d9a8e60061.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2969380952_9f1eb7f93b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/710878348_323082babd.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3005123298_d3017d5f5d.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3017656907_c3b137e070.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3143574389_8a4048fbe2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2763044275_aa498eb88b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2666205903_8d287669e1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3187492926_8aa85f80c6.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3109704348_c6416244ce.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2647229826_e0e0c65ef1.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/516998046_1175674fcd.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2273028514_d7b584f73d.jpg (deflated 2%)
#   adding: content/Flicker8k_Dataset/197142902_f05ff198c2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1112212364_0c48235fc2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/254475194_3d8f4dfd53.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3601803640_5f3cb05acf.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3582742297_1daa29968e.jpg (deflated 9%)
#   adding: content/Flicker8k_Dataset/3291255271_a185eba408.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3493844822_c315a11275.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3175712926_5a470d0886.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3447876218_4ccf42d7a0.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/2857558098_98e9249284.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2094810449_f8df9dcdf7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2804851816_9aae9071ca.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3109124656_626b596d5e.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3223302125_f8154417f4.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3489774350_a94e6c7bfc.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2552816307_c7c8e7f6b4.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2596100297_372bd0f739.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3348384389_73b6647017.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/241346709_23204cc2bc.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/179829865_095b040377.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2173677067_9d0732bcc2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3186527735_6e9fe2cf88.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/395461421_c586b136de.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1394620454_bf708cc501.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3506096155_13632955e8.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/479807115_3a484fb18b.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3725177385_62d5e13634.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3415311628_c220a65762.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3745451546_fc8ec70cbd.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3576536763_3c8c4f232e.jpg (deflated 2%)
#   adding: content/Flicker8k_Dataset/3350614753_5624e181b3.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3533451027_b078e4631b.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3098714492_19939e3b19.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3207775692_bb897d9afd.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2661567396_cbe4c2e5be.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1229756013_94663527d7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3430607596_7e4f74e3ff.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2866820467_ae699235a7.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3690425778_3b390b3ea5.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2670637584_d96efb8afa.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/324355356_859988a710.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3113322995_13781860f2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2923825744_ca125353f0.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/765298136_7805fbb079.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/271770120_880e8d8e52.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2234702530_a265a4df22.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/1884065356_c6c34b4568.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2853743795_e90ebc669d.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/1334892555_1beff092c3.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/483039719_75181b2726.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/3251460982_4578a568bb.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1956944011_c5661d3f22.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2346402952_e47d0065b6.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/1067180831_a59dc64344.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/1052358063_eae6744153.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2297471897_3419605c16.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/883040210_3c4a10f030.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/457945610_1a23b9ced0.jpg (deflated 1%)
#   adding: content/Flicker8k_Dataset/125319704_49ead3463c.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/488549693_a1f51d8c4a.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2246717855_c0c08fe5d2.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2899276965_a20b839cfd.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/270816949_ffad112278.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/2866093652_aa717eb9ce.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/86412576_c53392ef80.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3330019493_fd36fbc2ea.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/256283122_a4ef4a17cb.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3097171315_0ba7d283b1.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/152029243_b3582c36fa.jpg (deflated 0%)
#   adding: content/Flicker8k_Dataset/3600909823_ce72c26e66.jpg (deflated 2%)
#   adding: content/Flickr8k_Dataset.zip (stored 0%)
#   adding: content/captions/ (stored 0%)
#   adding: content/captions/dataset_coco.json (deflated 79%)
#   adding: content/captions/dataset_flickr8k.json (deflated 79%)
#   adding: content/captions/dataset_flickr30k.json (deflated 78%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/README.md (deflated 42%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)

# %%
files.download("/content/file.zip")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-7284e2301c58> in <module>()
# ----> 1 files.download('content')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in download(filename)
#     140       raise OSError(msg)
#     141     else:
# --> 142       raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     143
#     144   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: content

# %%
###################################
# Content of utils.py
###################################

import os
import numpy as np
import h5py
import json
import torch
from imageio import imread
from PIL import Image
from tqdm import tqdm
from collections import Counter
from random import seed, choice, sample


def create_input_files(dataset, karpathy_json_path, image_folder, captions_per_image, min_word_freq, output_folder,
                       max_len=100):
    """
    Creates input files for training, validation, and test data.

    :param dataset: name of dataset, one of 'coco', 'flickr8k', 'flickr30k'
    :param karpathy_json_path: path of Karpathy JSON file with splits and captions
    :param image_folder: folder with downloaded images
    :param captions_per_image: number of captions to sample per image
    :param min_word_freq: words occuring less frequently than this threshold are binned as <unk>s
    :param output_folder: folder to save files
    :param max_len: don't sample captions longer than this length
    """

    assert dataset in {'coco', 'flickr8k', 'flickr30k'}

    # Read Karpathy JSON
    with open(karpathy_json_path, 'r') as j:
        data = json.load(j)

    # Read image paths and captions for each image
    train_image_paths = []
    train_image_captions = []
    val_image_paths = []
    val_image_captions = []
    test_image_paths = []
    test_image_captions = []
    word_freq = Counter()

    for img in data['images']:
        captions = []
        for c in img['sentences']:
            # Update word frequency
            word_freq.update(c['tokens'])
            if len(c['tokens']) <= max_len:
                captions.append(c['tokens'])

        if len(captions) == 0:
            continue

        path = os.path.join(image_folder, img['filepath'], img['filename']) if dataset == 'coco' else os.path.join(
            image_folder, img['filename'])

        if img['split'] in {'train', 'restval'}:
            train_image_paths.append(path)
            train_image_captions.append(captions)
        elif img['split'] in {'val'}:
            val_image_paths.append(path)
            val_image_captions.append(captions)
        elif img['split'] in {'test'}:
            test_image_paths.append(path)
            test_image_captions.append(captions)

    # Sanity check
    assert len(train_image_paths) == len(train_image_captions)
    assert len(val_image_paths) == len(val_image_captions)
    assert len(test_image_paths) == len(test_image_captions)

    # Create word map
    words = [w for w in word_freq.keys() if word_freq[w] > min_word_freq]
    word_map = {k: v + 1 for v, k in enumerate(words)}
    word_map['<unk>'] = len(word_map) + 1
    word_map['<start>'] = len(word_map) + 1
    word_map['<end>'] = len(word_map) + 1
    word_map['<pad>'] = 0

    # Create a base/root name for all output files
    base_filename = dataset + '_' + str(captions_per_image) + '_cap_per_img_' + str(min_word_freq) + '_min_word_freq'

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Save word map to a JSON
    with open(os.path.join(output_folder, 'WORDMAP_' + base_filename + '.json'), 'w') as j:
        json.dump(word_map, j)

    # Sample captions for each image, save images to HDF5 file, and captions and their lengths to JSON files
    seed(123)
    for impaths, imcaps, split in [(train_image_paths, train_image_captions, 'TRAIN'),
                                   (val_image_paths, val_image_captions, 'VAL'),
                                   (test_image_paths, test_image_captions, 'TEST')]:

        with h5py.File(os.path.join(output_folder, split + '_IMAGES_' + base_filename + '.hdf5'), 'a') as h:
            # Make a note of the number of captions we are sampling per image
            h.attrs['captions_per_image'] = captions_per_image

            # Create dataset inside HDF5 file to store images
            images = h.create_dataset('images', (len(impaths), 3, 256, 256), dtype='uint8')

            print("\nReading %s images and captions, storing to file...\n" % split)

            enc_captions = []
            caplens = []

            for i, path in enumerate(tqdm(impaths)):

                # Sample captions
                if len(imcaps[i]) < captions_per_image:
                    captions = imcaps[i] + [choice(imcaps[i]) for _ in range(captions_per_image - len(imcaps[i]))]
                else:
                    captions = sample(imcaps[i], k=captions_per_image)

                # Sanity check
                assert len(captions) == captions_per_image

                # Read images
                img = imread(impaths[i])
                if len(img.shape) == 2:
                    img = img[:, :, np.newaxis]
                    img = np.concatenate([img, img, img], axis=2)
                #img = imresize(img, (256, 256))                
                img = np.array(Image.fromarray(img).resize((256, 256)))
                img = img.transpose(2, 0, 1)
                assert img.shape == (3, 256, 256)
                assert np.max(img) <= 255

                # Save image to HDF5 file
                images[i] = img

                for j, c in enumerate(captions):
                    # Encode captions
                    enc_c = [word_map['<start>']] + [word_map.get(word, word_map['<unk>']) for word in c] + [
                        word_map['<end>']] + [word_map['<pad>']] * (max_len - len(c))

                    # Find caption lengths
                    c_len = len(c) + 2

                    enc_captions.append(enc_c)
                    caplens.append(c_len)

            # Sanity check
            assert images.shape[0] * captions_per_image == len(enc_captions) == len(caplens)

            # Save encoded captions and their lengths to JSON files
            with open(os.path.join(output_folder, split + '_CAPTIONS_' + base_filename + '.json'), 'w') as j:
                json.dump(enc_captions, j)

            with open(os.path.join(output_folder, split + '_CAPLENS_' + base_filename + '.json'), 'w') as j:
                json.dump(caplens, j)


def init_embedding(embeddings):
    """
    Fills embedding tensor with values from the uniform distribution.

    :param embeddings: embedding tensor
    """
    bias = np.sqrt(3.0 / embeddings.size(1))
    torch.nn.init.uniform_(embeddings, -bias, bias)


def load_embeddings(emb_file, word_map):
    """
    Creates an embedding tensor for the specified word map, for loading into the model.

    :param emb_file: file containing embeddings (stored in GloVe format)
    :param word_map: word map
    :return: embeddings in the same order as the words in the word map, dimension of embeddings
    """

    # Find embedding dimension
    with open(emb_file, 'r') as f:
        emb_dim = len(f.readline().split(' ')) - 1

    vocab = set(word_map.keys())

    # Create tensor to hold embeddings, initialize
    embeddings = torch.FloatTensor(len(vocab), emb_dim)
    init_embedding(embeddings)

    # Read embedding file
    print("\nLoading embeddings...")
    for line in open(emb_file, 'r'):
        line = line.split(' ')

        emb_word = line[0]
        embedding = list(map(lambda t: float(t), filter(lambda n: n and not n.isspace(), line[1:])))

        # Ignore word if not in train_vocab
        if emb_word not in vocab:
            continue

        embeddings[word_map[emb_word]] = torch.FloatTensor(embedding)

    return embeddings, emb_dim


def clip_gradient(optimizer, grad_clip):
    """
    Clips gradients computed during backpropagation to avoid explosion of gradients.

    :param optimizer: optimizer with the gradients to be clipped
    :param grad_clip: clip value
    """
    for group in optimizer.param_groups:
        for param in group['params']:
            if param.grad is not None:
                param.grad.data.clamp_(-grad_clip, grad_clip)


def save_checkpoint(data_name, epoch, epochs_since_improvement, encoder, decoder, encoder_optimizer, decoder_optimizer,
                    bleu4, is_best):
    """
    Saves model checkpoint.

    :param data_name: base name of processed dataset
    :param epoch: epoch number
    :param epochs_since_improvement: number of epochs since last improvement in BLEU-4 score
    :param encoder: encoder model
    :param decoder: decoder model
    :param encoder_optimizer: optimizer to update encoder's weights, if fine-tuning
    :param decoder_optimizer: optimizer to update decoder's weights
    :param bleu4: validation BLEU-4 score for this epoch
    :param is_best: is this checkpoint the best so far?
    """
    state = {'epoch': epoch,
             'epochs_since_improvement': epochs_since_improvement,
             'bleu-4': bleu4,
             'encoder': encoder,
             'decoder': decoder,
             'encoder_optimizer': encoder_optimizer,
             'decoder_optimizer': decoder_optimizer}
    filename = 'checkpoint_' + data_name + '.pth.tar'
    torch.save(state, filename)
    # If this checkpoint is the best so far, store a copy so it doesn't get overwritten by a worse checkpoint
    if is_best:
        torch.save(state, 'BEST_' + filename)


class AverageMeter(object):
    """
    Keeps track of most recent, average, sum, and count of a metric.
    """

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count


def adjust_learning_rate(optimizer, shrink_factor):
    """
    Shrinks learning rate by a specified factor.

    :param optimizer: optimizer whose learning rate must be shrunk.
    :param shrink_factor: factor in interval (0, 1) to multiply learning rate with.
    """

    print("\nDECAYING learning rate.")
    for param_group in optimizer.param_groups:
        param_group['lr'] = param_group['lr'] * shrink_factor
    print("The new learning rate is %f\n" % (optimizer.param_groups[0]['lr'],))


def accuracy(scores, targets, k):
    """
    Computes top-k accuracy, from predicted and true labels.

    :param scores: scores from the model
    :param targets: true labels
    :param k: k in top-k accuracy
    :return: top-k accuracy
    """

    batch_size = targets.size(0)
    _, ind = scores.topk(k, 1, True, True)
    correct = ind.eq(targets.view(-1, 1).expand_as(ind))
    correct_total = correct.view(-1).float().sum()  # 0D tensor
    return correct_total.item() * (100.0 / batch_size)

# %%
###################################
# Content of create_input_files.py
###################################

import urllib.request
from tqdm import tqdm
import os
import zipfile

def download_hook(t):
    """Wraps tqdm instance.
    Don't forget to close() or __exit__()
    the tqdm instance once you're done with it (easiest using `with` syntax).
    Example
    -------
    >>> with tqdm(...) as t:
    ...     reporthook = my_hook(t)
    ...     urllib.request.urlretrieve(..., reporthook=reporthook)
    """
    last_b = [0]

    def update_to(b=1, bsize=1, tsize=None):
        """
        b  : int, optional
            Number of blocks transferred so far [default: 1].
        bsize  : int, optional
            Size of each block (in tqdm units) [default: 1].
        tsize  : int, optional
            Total size (in tqdm units). If [default: None] remains unchanged.
        """
        if tsize is not None:
            t.total = tsize
        t.update((b - last_b[0]) * bsize)
        last_b[0] = b

    return update_to

def download(url, save_dir):
    filename = url.split('/')[-1]
    with tqdm(unit = 'B', unit_scale = True, unit_divisor = 1024, miniters = 1, desc = filename) as t:
        urllib.request.urlretrieve(url, filename = os.path.join(save_dir, filename), reporthook = download_hook(t), data = None)

if __name__ == '__main__':
    # Download ground truth
    if not os.path.exists("caption_datasets.zip"):
        download("http://cs.stanford.edu/people/karpathy/deepimagesent/caption_datasets.zip", "./")
    # Extract in the correct folder
    with zipfile.ZipFile("caption_datasets.zip", 'r') as zip_ref:
        zip_ref.extractall("./captions")

    # Download and extract dataset images
    if not os.path.exists("Flickr8k_Dataset.zip"):
        download("https://github.com/jbrownlee/Datasets/releases/download/Flickr8k/Flickr8k_Dataset.zip", "./")
    with zipfile.ZipFile("Flickr8k_Dataset.zip", 'r') as zip_ref:
        zip_ref.extractall("./")

    # Create input files (along with word map)
    create_input_files(dataset='flickr8k',
                       karpathy_json_path='captions/dataset_flickr8k.json',
                       image_folder='Flicker8k_Dataset/',
                       captions_per_image=5,
                       min_word_freq=5,
                       output_folder='prepared_data/',
                       max_len=50)
# Out:
# caption_datasets.zip: 35.0MB [00:03, 11.3MB/s]
# Flickr8k_Dataset.zip: 1.04GB [00:36, 30.6MB/s]
# Reading TRAIN images and captions, storing to file...
# 100%|██████████| 6000/6000 [01:07<00:00, 88.95it/s]
# Reading VAL images and captions, storing to file...
# 100%|██████████| 1000/1000 [00:11<00:00, 86.87it/s]
# Reading TEST images and captions, storing to file...
# 100%|██████████| 1000/1000 [00:26<00:00, 38.33it/s]

# %%
###################################
# Content of datasets.py
###################################

import torch
from torch.utils.data import Dataset
import h5py
import json
import os


class CaptionDataset(Dataset):
    """
    A PyTorch Dataset class to be used in a PyTorch DataLoader to create batches.
    """

    def __init__(self, data_folder, data_name, split, transform=None):
        """
        :param data_folder: folder where data files are stored
        :param data_name: base name of processed datasets
        :param split: split, one of 'TRAIN', 'VAL', or 'TEST'
        :param transform: image transform pipeline
        """
        self.split = split
        assert self.split in {'TRAIN', 'VAL', 'TEST'}

        # Open hdf5 file where images are stored
        self.h = h5py.File(os.path.join(data_folder, self.split + '_IMAGES_' + data_name + '.hdf5'), 'r')
        self.imgs = self.h['images']

        # Captions per image
        self.cpi = self.h.attrs['captions_per_image']

        # Load encoded captions (completely into memory)
        with open(os.path.join(data_folder, self.split + '_CAPTIONS_' + data_name + '.json'), 'r') as j:
            self.captions = json.load(j)

        # Load caption lengths (completely into memory)
        with open(os.path.join(data_folder, self.split + '_CAPLENS_' + data_name + '.json'), 'r') as j:
            self.caplens = json.load(j)

        # PyTorch transformation pipeline for the image (normalizing, etc.)
        self.transform = transform

        # Total number of datapoints
        self.dataset_size = len(self.captions)

    def __getitem__(self, i):
        # Remember, the Nth caption corresponds to the (N // captions_per_image)th image
        img = torch.FloatTensor(self.imgs[i // self.cpi] / 255.)
        if self.transform is not None:
            img = self.transform(img)

        caption = torch.LongTensor(self.captions[i])

        caplen = torch.LongTensor([self.caplens[i]])

        if self.split is 'TRAIN':
            return img, caption, caplen
        else:
            # For validation of testing, also return all 'captions_per_image' captions to find BLEU-4 score
            all_captions = torch.LongTensor(
                self.captions[((i // self.cpi) * self.cpi):(((i // self.cpi) * self.cpi) + self.cpi)])
            return img, caption, caplen, all_captions

    def __len__(self):
        return self.dataset_size

# %%
###################################
# Content of models.py
###################################

import torch
from torch import nn
import torchvision

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


class Encoder(nn.Module):
    """
    Encoder.
    """

    def __init__(self, encoded_image_size=14):
        super(Encoder, self).__init__()
        self.enc_image_size = encoded_image_size

        resnet = torchvision.models.vgg16(pretrained=True)  # pretrained ImageNet ResNet-101

        # Remove linear and pool layers (since we're not doing classification)
        modules = list(resnet.children())[:-2]
        self.resnet = nn.Sequential(*modules)

        # Resize image to fixed size to allow input images of variable size
        self.adaptive_pool = nn.AdaptiveAvgPool2d((encoded_image_size, encoded_image_size))

        self.fine_tune()

    def forward(self, images):
        """
        Forward propagation.

        :param images: images, a tensor of dimensions (batch_size, 3, image_size, image_size)
        :return: encoded images
        """
        out = self.resnet(images)  # (batch_size, 512, image_size/32, image_size/32)
        out = self.adaptive_pool(out)  # (batch_size, 512, encoded_image_size, encoded_image_size)
        out = out.permute(0, 2, 3, 1)  # (batch_size, encoded_image_size, encoded_image_size, 512)
        return out

    def fine_tune(self, fine_tune=True):
        """
        Allow or prevent the computation of gradients for convolutional blocks 2 through 4 of the encoder.

        :param fine_tune: Allow?
        """
        for p in self.resnet.parameters():
            p.requires_grad = False
        # If fine-tuning, only fine-tune convolutional blocks 2 through 4
        for c in list(self.resnet.children())[5:]:
            for p in c.parameters():
                p.requires_grad = fine_tune


class Attention(nn.Module):
    """
    Attention Network.
    """

    def __init__(self, encoder_dim, decoder_dim, attention_dim):
        """
        :param encoder_dim: feature size of encoded images
        :param decoder_dim: size of decoder's RNN
        :param attention_dim: size of the attention network
        """
        super(Attention, self).__init__()
        self.encoder_att = nn.Linear(encoder_dim, attention_dim)  # linear layer to transform encoded image
        self.decoder_att = nn.Linear(decoder_dim, attention_dim)  # linear layer to transform decoder's output
        self.full_att = nn.Linear(attention_dim, 1)  # linear layer to calculate values to be softmax-ed
        self.relu = nn.ReLU()
        self.softmax = nn.Softmax(dim=1)  # softmax layer to calculate weights

    def forward(self, encoder_out, decoder_hidden):
        """
        Forward propagation.

        :param encoder_out: encoded images, a tensor of dimension (batch_size, num_pixels, encoder_dim)
        :param decoder_hidden: previous decoder output, a tensor of dimension (batch_size, decoder_dim)
        :return: attention weighted encoding, weights
        """
        att1 = self.encoder_att(encoder_out)  # (batch_size, num_pixels, attention_dim)
        att2 = self.decoder_att(decoder_hidden)  # (batch_size, attention_dim)
        att = self.full_att(self.relu(att1 + att2.unsqueeze(1))).squeeze(2)  # (batch_size, num_pixels)
        alpha = self.softmax(att)  # (batch_size, num_pixels)
        attention_weighted_encoding = (encoder_out * alpha.unsqueeze(2)).sum(dim=1)  # (batch_size, encoder_dim)

        return attention_weighted_encoding, alpha


class DecoderWithAttention(nn.Module):
    """
    Decoder.
    """

    def __init__(self, attention_dim, embed_dim, decoder_dim, vocab_size, encoder_dim=512, dropout=0.5):
        """
        :param attention_dim: size of attention network
        :param embed_dim: embedding size
        :param decoder_dim: size of decoder's RNN
        :param vocab_size: size of vocabulary
        :param encoder_dim: feature size of encoded images
        :param dropout: dropout
        """
        super(DecoderWithAttention, self).__init__()

        self.encoder_dim = encoder_dim
        self.attention_dim = attention_dim
        self.embed_dim = embed_dim
        self.decoder_dim = decoder_dim
        self.vocab_size = vocab_size
        self.dropout = dropout

        self.attention = Attention(encoder_dim, decoder_dim, attention_dim)  # attention network

        self.embedding = nn.Embedding(vocab_size, embed_dim)  # embedding layer
        self.dropout = nn.Dropout(p=self.dropout)
        #self.decode_step = nn.LSTMCell(embed_dim + encoder_dim, decoder_dim, bias=True)  # decoding LSTMCell
        self.decode_step = nn.GRUCell(embed_dim + encoder_dim, decoder_dim, bias=True)
        self.init_h = nn.Linear(encoder_dim, decoder_dim)  # linear layer to find initial hidden state of LSTMCell
        #self.init_c = nn.Linear(encoder_dim, decoder_dim)  # linear layer to find initial cell state of LSTMCell
        self.f_beta = nn.Linear(decoder_dim, encoder_dim)  # linear layer to create a sigmoid-activated gate
        self.sigmoid = nn.Sigmoid()
        self.fc = nn.Linear(decoder_dim, vocab_size)  # linear layer to find scores over vocabulary
        self.init_weights()  # initialize some layers with the uniform distribution

    def init_weights(self):
        """
        Initializes some parameters with values from the uniform distribution, for easier convergence.
        """
        self.embedding.weight.data.uniform_(-0.1, 0.1)
        self.fc.bias.data.fill_(0)
        self.fc.weight.data.uniform_(-0.1, 0.1)

    def load_pretrained_embeddings(self, embeddings):
        """
        Loads embedding layer with pre-trained embeddings.

        :param embeddings: pre-trained embeddings
        """
        self.embedding.weight = nn.Parameter(embeddings)

    def fine_tune_embeddings(self, fine_tune=True):
        """
        Allow fine-tuning of embedding layer? (Only makes sense to not-allow if using pre-trained embeddings).

        :param fine_tune: Allow?
        """
        for p in self.embedding.parameters():
            p.requires_grad = fine_tune

    def init_hidden_state(self, encoder_out):
        """
        Creates the initial hidden and cell states for the decoder's LSTM based on the encoded images.

        :param encoder_out: encoded images, a tensor of dimension (batch_size, num_pixels, encoder_dim)
        :return: hidden state, cell state
        """
        mean_encoder_out = encoder_out.mean(dim=1)
        h = self.init_h(mean_encoder_out)  # (batch_size, decoder_dim)
        # c = self.init_c(mean_encoder_out)
        return h

    def forward(self, encoder_out, encoded_captions, caption_lengths, proba=1):
        """
        Forward propagation.

        :param encoder_out: encoded images, a tensor of dimension (batch_size, enc_image_size, enc_image_size, encoder_dim)
        :param encoded_captions: encoded captions, a tensor of dimension (batch_size, max_caption_length)
        :param caption_lengths: caption lengths, a tensor of dimension (batch_size, 1)
        :return: scores for vocabulary, sorted encoded captions, decode lengths, weights, sort indices
        """

        batch_size = encoder_out.size(0)
        encoder_dim = encoder_out.size(-1)
        vocab_size = self.vocab_size

        # Flatten image
        encoder_out = encoder_out.view(batch_size, -1, encoder_dim)  # (batch_size, num_pixels, encoder_dim)
        num_pixels = encoder_out.size(1)

        # Sort input data by decreasing lengths; why? apparent below
        caption_lengths, sort_ind = caption_lengths.squeeze(1).sort(dim=0, descending=True)
        encoder_out = encoder_out[sort_ind]
        encoded_captions = encoded_captions[sort_ind]

        # Embedding
        embeddings = self.embedding(encoded_captions)  # (batch_size, max_caption_length, embed_dim)

        # Initialize LSTM state
        h = self.init_hidden_state(encoder_out)  # (batch_size, decoder_dim)

        # We won't decode at the <end> position, since we've finished generating as soon as we generate <end>
        # So, decoding lengths are actual lengths - 1
        decode_lengths = (caption_lengths - 1).tolist()

        # Create tensors to hold word predicion scores and alphas
        predictions = torch.zeros(batch_size, max(decode_lengths), vocab_size).to(device)
        alphas = torch.zeros(batch_size, max(decode_lengths), num_pixels).to(device)

        # At each time-step, decode by
        # attention-weighing the encoder's output based on the decoder's previous hidden state output
        # then generate a new word in the decoder with the previous word and the attention weighted encoding

        # Utilisation du GRU, modification enlever c 
        # Partie à modifier pour le schedule sampling 
        # On ne veut plus prendre ce qui correspond à la phrase correcte mais on va prendre ce qui correspond à la sortie de notre réseau
        # On récupère la variable prédiction qu'il faut embeded et la donner au réseau
        # Récupérer le mot prédit par le réseau à l'itération précédente et récuperer l'embedding qui correspond au mot et donner cette entrée au réseau 
        # On alterne une situation ou on prend l'embedding du réseau pour entrée et le mot correcte de l'itération précédente. 
        # Teacher-forcing autre nom de shedule sampling, utiliser un schéma de décroissance. Au début on utilise uniquement le mot correcte puis petit à petit, on utilise le mot générer par le réseau
        # Retrouver le mot sortie par le réseau check les fonctions d'évalution où on réalise cette opération 
        #print('int_size')
        # print(f'embeddings size {embeddings.size()}')
        # print(f'encoded caption size {encoded_caption.size()}')
        #print('___    ___')
        for t in range(max(decode_lengths)):
            batch_size_t = sum([l > t for l in decode_lengths])
            attention_weighted_encoding, alpha = self.attention(encoder_out[:batch_size_t],h[:batch_size_t])
            gate = self.sigmoid(self.f_beta(h[:batch_size_t]))  # gating scalar, (batch_size_t, encoder_dim)
            attention_weighted_encoding = gate * attention_weighted_encoding
            prob = np.random.random() 
            if t == 0 or proba > prob :
              h = self.decode_step(torch.cat([embeddings[:batch_size_t, t, :], attention_weighted_encoding], dim=1), h[:batch_size_t])  # (batch_size_t, decoder_dim)
            else :
              h = self.decode_step(torch.cat([embeddings_pred[:batch_size_t], attention_weighted_encoding], dim=1), h[:batch_size_t])  # (batch_size_t, decoder_dim)
            preds = self.fc(self.dropout(h))  # (batch_size_t, vocab_size)
            predictions[:batch_size_t, t, :] = preds
            alphas[:batch_size_t, t, :] = alpha
            embeddings_pred = self.embedding(torch.argmax(preds, dim=1))

            # print(f'h size : {h.size()}')
            # print(f'preds.size {preds.size()}')
            # print(f'prediction.size {predictions.size()}')
            # print(f'alpha.size {alpha.size()}')
            # print(f'attention_weighted_encoding.size {attention_weighted_encoding.size()}')
            # print(f'GRU input size {torch.cat([embeddings[:batch_size_t, t, :], attention_weighted_encoding], dim=1).size()}')


        return predictions, encoded_captions, decode_lengths, alphas, sort_ind

# %%
###################################
# Content of train.py
###################################

import time
import torch.backends.cudnn as cudnn
import torch.optim
import torch.utils.data
import torchvision.transforms as transforms
from torch import nn
from torch.nn.utils.rnn import pack_padded_sequence
from nltk.translate.bleu_score import corpus_bleu

# Data parameters
data_folder = 'prepared_data/'  # folder with data files saved by create_input_files.py
data_name = 'flickr8k_5_cap_per_img_5_min_word_freq'  # base name shared by data files

# Model parameters
emb_dim = 512  # dimension of word embeddings
attention_dim = 512  # dimension of attention linear layers
decoder_dim = 512  # dimension of decoder RNN
dropout = 0.5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # sets device for model and PyTorch tensors
cudnn.benchmark = True  # set to true only if inputs to model are fixed size; otherwise lot of computational overhead

# Training parameters
start_epoch = 0
epochs = 5  # number of epochs to train for (if early stopping is not triggered)
epochs_since_improvement = 0  # keeps track of number of epochs since there's been an improvement in validation BLEU
batch_size = 32
workers = 0  # for data-loading; right now, only 1 works with h5py
encoder_lr = 1e-4  # learning rate for encoder if fine-tuning
decoder_lr = 4e-4  # learning rate for decoder
grad_clip = 5.  # clip gradients at an absolute value of
alpha_c = 1.  # regularization parameter for 'doubly stochastic attention', as in the paper
best_bleu4 = 0.  # BLEU-4 score right now
print_freq = 100  # print training/validation stats every __ batches
fine_tune_encoder = False  # fine-tune encoder?
checkpoint = None  # path to checkpoint, None if none


def main():
    """
    Training and validation.
    """

    global best_bleu4, epochs_since_improvement, checkpoint, start_epoch, fine_tune_encoder, data_name, word_map

    # Read word map
    word_map_file = os.path.join(data_folder, 'WORDMAP_' + data_name + '.json')
    with open(word_map_file, 'r') as j:
        word_map = json.load(j)

    # Initialize / load checkpoint
    if checkpoint is None:
        decoder = DecoderWithAttention(attention_dim=attention_dim,
                                       embed_dim=emb_dim,
                                       decoder_dim=decoder_dim,
                                       vocab_size=len(word_map),
                                       dropout=dropout)
        decoder_optimizer = torch.optim.Adam(params=filter(lambda p: p.requires_grad, decoder.parameters()),
                                             lr=decoder_lr)
        encoder = Encoder()
        encoder.fine_tune(fine_tune_encoder)
        encoder_optimizer = torch.optim.Adam(params=filter(lambda p: p.requires_grad, encoder.parameters()),
                                             lr=encoder_lr) if fine_tune_encoder else None

    else:
        checkpoint = torch.load(checkpoint)
        start_epoch = checkpoint['epoch'] + 1
        epochs_since_improvement = checkpoint['epochs_since_improvement']
        best_bleu4 = checkpoint['bleu-4']
        decoder = checkpoint['decoder']
        decoder_optimizer = checkpoint['decoder_optimizer']
        encoder = checkpoint['encoder']
        encoder_optimizer = checkpoint['encoder_optimizer']
        if fine_tune_encoder is True and encoder_optimizer is None:
            encoder.fine_tune(fine_tune_encoder)
            encoder_optimizer = torch.optim.Adam(params=filter(lambda p: p.requires_grad, encoder.parameters()),
                                                 lr=encoder_lr)

    # Move to GPU, if available
    decoder = decoder.to(device)
    encoder = encoder.to(device)

    # Loss function
    criterion = nn.CrossEntropyLoss().to(device)

    # Custom dataloaders
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])
    train_loader = torch.utils.data.DataLoader(
        CaptionDataset(data_folder, data_name, 'TRAIN', transform=transforms.Compose([normalize])),
        batch_size=batch_size, shuffle=True, num_workers=workers, pin_memory=True)
    val_loader = torch.utils.data.DataLoader(
        CaptionDataset(data_folder, data_name, 'VAL', transform=transforms.Compose([normalize])),
        batch_size=batch_size, shuffle=True, num_workers=workers, pin_memory=True)

    # Epochs
    for epoch in range(start_epoch, epochs):

        # Decay learning rate if there is no improvement for 8 consecutive epochs, and terminate training after 20
        if epochs_since_improvement == 20:
            break
        if epochs_since_improvement > 0 and epochs_since_improvement % 8 == 0:
            adjust_learning_rate(decoder_optimizer, 0.8)
            if fine_tune_encoder:
                adjust_learning_rate(encoder_optimizer, 0.8)

        # One epoch's training
        train(train_loader=train_loader,
              encoder=encoder,
              decoder=decoder,
              criterion=criterion,
              encoder_optimizer=encoder_optimizer,
              decoder_optimizer=decoder_optimizer,
              epoch=epoch)

        # One epoch's validation
        recent_bleu4 = validate(val_loader=val_loader,
                                encoder=encoder,
                                decoder=decoder,
                                criterion=criterion)

        # Check if there was an improvement
        is_best = recent_bleu4 > best_bleu4
        best_bleu4 = max(recent_bleu4, best_bleu4)
        if not is_best:
            epochs_since_improvement += 1
            print("\nEpochs since last improvement: %d\n" % (epochs_since_improvement,))
        else:
            epochs_since_improvement = 0

        # Save checkpoint
        save_checkpoint(data_name, epoch, epochs_since_improvement, encoder, decoder, encoder_optimizer,
                        decoder_optimizer, recent_bleu4, is_best)


def train(train_loader, encoder, decoder, criterion, encoder_optimizer, decoder_optimizer, epoch):
    """
    Performs one epoch's training.

    :param train_loader: DataLoader for training data
    :param encoder: encoder model
    :param decoder: decoder model
    :param criterion: loss layer
    :param encoder_optimizer: optimizer to update encoder's weights (if fine-tuning)
    :param decoder_optimizer: optimizer to update decoder's weights
    :param epoch: epoch number
    """

    decoder.train()  # train mode (dropout and batchnorm is used)
    encoder.train()

    batch_time = AverageMeter()  # forward prop. + back prop. time
    data_time = AverageMeter()  # data loading time
    losses = AverageMeter()  # loss (per word decoded)
    top5accs = AverageMeter()  # top5 accuracy

    start = time.time()

    # Batches
    for i, (imgs, caps, caplens) in enumerate(train_loader):
        data_time.update(time.time() - start)

        # Move to GPU, if available
        imgs = imgs.to(device)
        caps = caps.to(device)
        caplens = caplens.to(device)

        # Forward prop.
        imgs = encoder(imgs)

        proba = 1 - np.exp( 3*i*epoch/(5*len(train_loader)))
        scores, caps_sorted, decode_lengths, alphas, sort_ind = decoder(imgs, caps, caplens, proba)

        # Since we decoded starting with <start>, the targets are all words after <start>, up to <end>
        targets = caps_sorted[:, 1:]

        # Remove timesteps that we didn't decode at, or are pads
        # pack_padded_sequence is an easy trick to do this
        scores = pack_padded_sequence(scores, decode_lengths, batch_first=True).data
        targets = pack_padded_sequence(targets, decode_lengths, batch_first=True).data

        # Calculate loss
        loss = criterion(scores, targets)

        # Add doubly stochastic attention regularization
        loss += alpha_c * ((1. - alphas.sum(dim=1)) ** 2).mean()

        # Back prop.
        decoder_optimizer.zero_grad()
        if encoder_optimizer is not None:
            encoder_optimizer.zero_grad()
        loss.backward()

        # Clip gradients
        if grad_clip is not None:
            clip_gradient(decoder_optimizer, grad_clip)
            if encoder_optimizer is not None:
                clip_gradient(encoder_optimizer, grad_clip)

        # Update weights
        decoder_optimizer.step()
        if encoder_optimizer is not None:
            encoder_optimizer.step()

        # Keep track of metrics
        top5 = accuracy(scores, targets, 5)
        losses.update(loss.item(), sum(decode_lengths))
        top5accs.update(top5, sum(decode_lengths))
        batch_time.update(time.time() - start)

        start = time.time()

        # Print status
        if i % print_freq == 0:
            print('Epoch: [{0}][{1}/{2}]\t'
                  'Batch Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                  'Data Load Time {data_time.val:.3f} ({data_time.avg:.3f})\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                  'Top-5 Accuracy {top5.val:.3f} ({top5.avg:.3f})'.format(epoch, i, len(train_loader),
                                                                          batch_time=batch_time,
                                                                          data_time=data_time, loss=losses,
                                                                          top5=top5accs))


def validate(val_loader, encoder, decoder, criterion):
    """
    Performs one epoch's validation.

    :param val_loader: DataLoader for validation data.
    :param encoder: encoder model
    :param decoder: decoder model
    :param criterion: loss layer
    :return: BLEU-4 score
    """
    decoder.eval()  # eval mode (no dropout or batchnorm)
    if encoder is not None:
        encoder.eval()

    batch_time = AverageMeter()
    losses = AverageMeter()
    top5accs = AverageMeter()

    start = time.time()

    references = list()  # references (true captions) for calculating BLEU-4 score
    hypotheses = list()  # hypotheses (predictions)

    # explicitly disable gradient calculation to avoid CUDA memory error
    # solves the issue #57
    with torch.no_grad():
        # Batches
        for i, (imgs, caps, caplens, allcaps) in enumerate(val_loader):

            # Move to device, if available
            imgs = imgs.to(device)
            caps = caps.to(device)
            caplens = caplens.to(device)

            # Forward prop.
            if encoder is not None:
                imgs = encoder(imgs)
            scores, caps_sorted, decode_lengths, alphas, sort_ind = decoder(imgs, caps, caplens)

            # Since we decoded starting with <start>, the targets are all words after <start>, up to <end>
            targets = caps_sorted[:, 1:]

            # Remove timesteps that we didn't decode at, or are pads
            # pack_padded_sequence is an easy trick to do this
            scores_copy = scores.clone()
            scores = pack_padded_sequence(scores, decode_lengths, batch_first=True).data
            targets = pack_padded_sequence(targets, decode_lengths, batch_first=True).data

            # Calculate loss
            loss = criterion(scores, targets)

            # Add doubly stochastic attention regularization
            loss += alpha_c * ((1. - alphas.sum(dim=1)) ** 2).mean()

            # Keep track of metrics
            losses.update(loss.item(), sum(decode_lengths))
            top5 = accuracy(scores, targets, 5)
            top5accs.update(top5, sum(decode_lengths))
            batch_time.update(time.time() - start)

            start = time.time()

            if i % print_freq == 0:
                print('Validation: [{0}/{1}]\t'
                      'Batch Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                      'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                      'Top-5 Accuracy {top5.val:.3f} ({top5.avg:.3f})\t'.format(i, len(val_loader), batch_time=batch_time,
                                                                                loss=losses, top5=top5accs))

            # Store references (true captions), and hypothesis (prediction) for each image
            # If for n images, we have n hypotheses, and references a, b, c... for each image, we need -
            # references = [[ref1a, ref1b, ref1c], [ref2a, ref2b], ...], hypotheses = [hyp1, hyp2, ...]

            # References
            allcaps = allcaps[sort_ind]  # because images were sorted in the decoder
            for j in range(allcaps.shape[0]):
                img_caps = allcaps[j].tolist()
                img_captions = list(
                    map(lambda c: [w for w in c if w not in {word_map['<start>'], word_map['<pad>']}],
                        img_caps))  # remove <start> and pads
                references.append(img_captions)

            # Hypotheses
            _, preds = torch.max(scores_copy, dim=2)
            preds = preds.tolist()
            temp_preds = list()
            for j, p in enumerate(preds):
                temp_preds.append(preds[j][:decode_lengths[j]])  # remove pads
            preds = temp_preds
            hypotheses.extend(preds)

            assert len(references) == len(hypotheses)

        # Calculate BLEU-4 scores
        bleu4 = corpus_bleu(references, hypotheses)

        print(
            '\n * LOSS - {loss.avg:.3f}, TOP-5 ACCURACY - {top5.avg:.3f}, BLEU-4 - {bleu}\n'.format(
                loss=losses,
                top5=top5accs,
                bleu=bleu4))

    return bleu4


if __name__ == '__main__':
    main()
# Out:
# Epoch: [0][0/938]	Batch Time 25.228 (25.228)	Data Load Time 0.076 (0.076)	Loss 8.7856 (8.7856)	Top-5 Accuracy 0.777 (0.777)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-37f07472ee2f> in <module>()
#     332
#     333 if __name__ == '__main__':
# --> 334     main()
#
# <ipython-input-7-37f07472ee2f> in main()
#     115               encoder_optimizer=encoder_optimizer,
#     116               decoder_optimizer=decoder_optimizer,
# --> 117               epoch=epoch)
#     118
#     119         # One epoch's validation
#
# <ipython-input-7-37f07472ee2f> in train(train_loader, encoder, decoder, criterion, encoder_optimizer, decoder_optimizer, epoch)
#     173
#     174         proba = 1 - np.exp( 3*i*epoch/(5*len(train_loader)))
# --> 175         scores, caps_sorted, decode_lengths, alphas, sort_ind = decoder(imgs, caps, caplens, proba)
#     176
#     177         # Since we decoded starting with <start>, the targets are all words after <start>, up to <end>
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-6-c3edd3406fd6> in forward(self, encoder_out, encoded_captions, caption_lengths, proba)
#     226               h = self.decode_step(torch.cat([embeddings[:batch_size_t, t, :], attention_weighted_encoding], dim=1), h[:batch_size_t])  # (batch_size_t, decoder_dim)
#     227             else :
# --> 228               h = self.decode_step(torch.cat([embeddings_pred[:batch_size_t], attention_weighted_encoding], dim=1), h[:batch_size_t])  # (batch_size_t, decoder_dim)
#     229             preds = self.fc(self.dropout(h))  # (batch_size_t, vocab_size)
#     230             predictions[:batch_size_t, t, :] = preds
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#    1145             input, hx,
#    1146             self.weight_ih, self.weight_hh,
# -> 1147             self.bias_ih, self.bias_hh,
#    1148         )
#
# KeyboardInterrupt:

# %%
###################################
# Content of caption.py
###################################

import torch
import torch.nn.functional as F
import numpy as np
import json
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import skimage.transform
import argparse
from imageio import imread 
from PIL import Image

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


def caption_image_beam_search(encoder, decoder, image_path, word_map, beam_size=3):
    """
    Reads an image and captions it with beam search.

    :param encoder: encoder model
    :param decoder: decoder model
    :param image_path: path to image
    :param word_map: word map
    :param beam_size: number of sequences to consider at each decode-step
    :return: caption, weights for visualization
    """

    k = beam_size
    vocab_size = len(word_map)

    # Read image and process
    img = imread(image_path)
    if len(img.shape) == 2:
        img = img[:, :, np.newaxis]
        img = np.concatenate([img, img, img], axis=2)
    img = np.array(Image.fromarray(img).resize((256, 256)))
    img = img.transpose(2, 0, 1)
    img = img / 255.
    img = torch.FloatTensor(img).to(device)
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])
    transform = transforms.Compose([normalize])
    image = transform(img)  # (3, 256, 256)

    # Encode
    image = image.unsqueeze(0)  # (1, 3, 256, 256)
    encoder_out = encoder(image)  # (1, enc_image_size, enc_image_size, encoder_dim)
    enc_image_size = encoder_out.size(1)
    encoder_dim = encoder_out.size(3)

    # Flatten encoding
    encoder_out = encoder_out.view(1, -1, encoder_dim)  # (1, num_pixels, encoder_dim)
    num_pixels = encoder_out.size(1)

    # We'll treat the problem as having a batch size of k
    encoder_out = encoder_out.expand(k, num_pixels, encoder_dim)  # (k, num_pixels, encoder_dim)

    # Tensor to store top k previous words at each step; now they're just <start>
    k_prev_words = torch.LongTensor([[word_map['<start>']]] * k).to(device)  # (k, 1)

    # Tensor to store top k sequences; now they're just <start>
    seqs = k_prev_words  # (k, 1)

    # Tensor to store top k sequences' scores; now they're just 0
    top_k_scores = torch.zeros(k, 1).to(device)  # (k, 1)

    # Tensor to store top k sequences' alphas; now they're just 1s
    seqs_alpha = torch.ones(k, 1, enc_image_size, enc_image_size).to(device)  # (k, 1, enc_image_size, enc_image_size)

    # Lists to store completed sequences, their alphas and scores
    complete_seqs = list()
    complete_seqs_alpha = list()
    complete_seqs_scores = list()

    # Start decoding
    step = 1
    h = decoder.init_hidden_state(encoder_out)

    # s is a number less than or equal to k, because sequences are removed from this process once they hit <end>
    while True:

        embeddings = decoder.embedding(k_prev_words).squeeze(1)  # (s, embed_dim)

        awe, alpha = decoder.attention(encoder_out, h)  # (s, encoder_dim), (s, num_pixels)

        alpha = alpha.view(-1, enc_image_size, enc_image_size)  # (s, enc_image_size, enc_image_size)

        gate = decoder.sigmoid(decoder.f_beta(h))  # gating scalar, (s, encoder_dim)
        awe = gate * awe

        h = decoder.decode_step(torch.cat([embeddings, awe], dim=1), h)  # (s, decoder_dim)

        scores = decoder.fc(h)  # (s, vocab_size)
        scores = F.log_softmax(scores, dim=1)

        # Add
        scores = top_k_scores.expand_as(scores) + scores  # (s, vocab_size)

        # For the first step, all k points will have the same scores (since same k previous words, h, c)
        if step == 1:
            top_k_scores, top_k_words = scores[0].topk(k, 0, True, True)  # (s)
        else:
            # Unroll and find top scores, and their unrolled indices
            top_k_scores, top_k_words = scores.view(-1).topk(k, 0, True, True)  # (s)

        # Convert unrolled indices to actual indices of scores
        prev_word_inds = top_k_words // vocab_size  # (s) # MODIF
        next_word_inds = top_k_words % vocab_size  # (s)

        # Add new words to sequences, alphas
        seqs = torch.cat([seqs[prev_word_inds], next_word_inds.unsqueeze(1)], dim=1)  # (s, step+1)
        seqs_alpha = torch.cat([seqs_alpha[prev_word_inds], alpha[prev_word_inds].unsqueeze(1)],
                               dim=1)  # (s, step+1, enc_image_size, enc_image_size)

        # Which sequences are incomplete (didn't reach <end>)?
        incomplete_inds = [ind for ind, next_word in enumerate(next_word_inds) if
                           next_word != word_map['<end>']]
        complete_inds = list(set(range(len(next_word_inds))) - set(incomplete_inds))

        # Set aside complete sequences
        if len(complete_inds) > 0:
            complete_seqs.extend(seqs[complete_inds].tolist())
            complete_seqs_alpha.extend(seqs_alpha[complete_inds].tolist())
            complete_seqs_scores.extend(top_k_scores[complete_inds])
        k -= len(complete_inds)  # reduce beam length accordingly

        # Proceed with incomplete sequences
        if k == 0:
            break
        seqs = seqs[incomplete_inds]
        seqs_alpha = seqs_alpha[incomplete_inds]
        h = h[prev_word_inds[incomplete_inds]]
        encoder_out = encoder_out[prev_word_inds[incomplete_inds]]
        top_k_scores = top_k_scores[incomplete_inds].unsqueeze(1)
        k_prev_words = next_word_inds[incomplete_inds].unsqueeze(1)

        # Break if things have been going on too long
        if step > 50:
            break
        step += 1

    i = complete_seqs_scores.index(max(complete_seqs_scores))
    seq = complete_seqs[i]
    alphas = complete_seqs_alpha[i]

    return seq, alphas


def visualize_att(image_path, seq, alphas, rev_word_map, smooth=True):
    """
    Visualizes caption with weights at every word.

    Adapted from paper authors' repo: https://github.com/kelvinxu/arctic-captions/blob/master/alpha_visualization.ipynb

    :param image_path: path to image that has been captioned
    :param seq: caption
    :param alphas: weights
    :param rev_word_map: reverse word mapping, i.e. ix2word
    :param smooth: smooth weights?
    """
    image = Image.open(image_path)
    image = image.resize([14 * 24, 14 * 24], Image.LANCZOS)

    words = [rev_word_map[ind] for ind in seq]

    for t in range(len(words)):
        if t > 50:
            break
        plt.subplot(np.ceil(len(words) / 5.), 5, t + 1)

        plt.text(0, 1, '%s' % (words[t]), color='black', backgroundcolor='white', fontsize=12)
        plt.imshow(image)
        current_alpha = alphas[t, :]
        if smooth:
            alpha = skimage.transform.pyramid_expand(current_alpha.numpy(), upscale=24, sigma=8)
        else:
            alpha = skimage.transform.resize(current_alpha.numpy(), [14 * 24, 14 * 24])
        if t == 0:
            plt.imshow(alpha, alpha=0)
        else:
            plt.imshow(alpha, alpha=0.8)
        plt.set_cmap(cm.Greys_r)
        plt.axis('off')
    plt.show()


if __name__ == '__main__':
    parser = argparse.ArgumentParser(description='Show, Attend, and Tell - Tutorial - Generate Caption')

    #parser.add_argument('--img', '-i', help='path to image')
    #parser.add_argument('--model', '-m', help='path to model')
    #parser.add_argument('--word_map', '-wm', help='path to word map JSON')
    #parser.add_argument('--beam_size', '-b', default=5, type=int, help='beam size for beam search')
    #parser.add_argument('--dont_smooth', dest='smooth', action='store_false', help='do not smooth alpha overlay')

    args = {
        'img' : 'Flicker8k_Dataset/1479124077_17dcc0d5d7.jpg', #'Flicker8k_Dataset/582899605_d96f9201f1.jpg', ,  'Flicker8k_Dataset/667626_18933d713e.jpg'
        #'Flicker8k_Dataset/2411824767_4eb1fae823.jpg', 'Flicker8k_Dataset/3128856481_86e5df4160.jpg', 'Flicker8k_Dataset/582899605_d96f9201f1.jpg'
        'model': 'BEST_checkpoint_flickr8k_5_cap_per_img_5_min_word_freq.pth.tar',
        'word_map' : 'prepared_data/WORDMAP_flickr8k_5_cap_per_img_5_min_word_freq.json',
        'beam_size' : 5,
        'smooth' : 'false'
        }
    
    #args = parser.parse_args()

    # Load model
    checkpoint = torch.load(args['model'], map_location=str(device))
    decoder = checkpoint['decoder']
    decoder = decoder.to(device)
    decoder.eval()
    encoder = checkpoint['encoder']
    encoder = encoder.to(device)
    encoder.eval()

    # Load word map (word2ix)
    with open(args['word_map'], 'r') as j:
        word_map = json.load(j)
    rev_word_map = {v: k for k, v in word_map.items()}  # ix2word

    # Encode, decode with attention and beam search
    seq, alphas = caption_image_beam_search(encoder, decoder, args['img'], word_map, args['beam_size'])
    alphas = torch.FloatTensor(alphas)

    # Visualize caption and attention of best sequence
    visualize_att(args['img'], seq, alphas, rev_word_map, args['smooth'])

# %%
img = Image.open('Flicker8k_Dataset/1479124077_17dcc0d5d7.jpg')
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-09d35ef80fc0> in <module>()
# ----> 1 img = Image.open('Flicker8k_Dataset/1479124077_17dcc0d5d7.jpg')
#       2 plt.imshow(img)
#
# NameError: name 'Image' is not defined

# %%
###################################
# Content of eval.py
###################################

import torch.backends.cudnn as cudnn
import torch.optim
import torch.utils.data
import torchvision.transforms as transforms
from nltk.translate.bleu_score import corpus_bleu
import torch.nn.functional as F
from tqdm import tqdm

# Parameters
data_folder = 'prepared_data/'  # folder with data files saved by create_input_files.py
data_name = 'flickr8k_5_cap_per_img_5_min_word_freq'  # base name shared by data files
checkpoint = 'BEST_checkpoint_flickr8k_5_cap_per_img_5_min_word_freq.pth.tar'  # model checkpoint
word_map_file = 'prepared_data/WORDMAP_flickr8k_5_cap_per_img_5_min_word_freq.json'  # word map, ensure it's the same the data was encoded with and the model was trained with
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # sets device for model and PyTorch tensors
cudnn.benchmark = True  # set to true only if inputs to model are fixed size; otherwise lot of computational overhead

# Load model
checkpoint = torch.load(checkpoint)
decoder = checkpoint['decoder']
decoder = decoder.to(device)
decoder.eval()
encoder = checkpoint['encoder']
encoder = encoder.to(device)
encoder.eval()

# Load word map (word2ix)
with open(word_map_file, 'r') as j:
    word_map = json.load(j)
rev_word_map = {v: k for k, v in word_map.items()}
vocab_size = len(word_map)

# Normalization transform
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])


def evaluate(beam_size):
    """
    Evaluation

    :param beam_size: beam size at which to generate captions for evaluation
    :return: BLEU-4 score
    """
    # DataLoader
    loader = torch.utils.data.DataLoader(
        CaptionDataset(data_folder, data_name, 'TEST', transform=transforms.Compose([normalize])),
        batch_size=1, shuffle=True, num_workers=1, pin_memory=True)

    # TODO: Batched Beam Search
    # Therefore, do not use a batch_size greater than 1 - IMPORTANT!

    # Lists to store references (true captions), and hypothesis (prediction) for each image
    # If for n images, we have n hypotheses, and references a, b, c... for each image, we need -
    # references = [[ref1a, ref1b, ref1c], [ref2a, ref2b], ...], hypotheses = [hyp1, hyp2, ...]
    references = list()
    hypotheses = list()

    # For each image
    for i, (image, caps, caplens, allcaps) in enumerate(
            tqdm(loader, desc="EVALUATING AT BEAM SIZE " + str(beam_size))):

        k = beam_size

        # Move to GPU device, if available
        image = image.to(device)  # (1, 3, 256, 256)

        # Encode
        encoder_out = encoder(image)  # (1, enc_image_size, enc_image_size, encoder_dim)
        enc_image_size = encoder_out.size(1)
        encoder_dim = encoder_out.size(3)

        # Flatten encoding
        encoder_out = encoder_out.view(1, -1, encoder_dim)  # (1, num_pixels, encoder_dim)
        num_pixels = encoder_out.size(1)

        # We'll treat the problem as having a batch size of k
        encoder_out = encoder_out.expand(k, num_pixels, encoder_dim)  # (k, num_pixels, encoder_dim)

        # Tensor to store top k previous words at each step; now they're just <start>
        k_prev_words = torch.LongTensor([[word_map['<start>']]] * k).to(device)  # (k, 1)

        # Tensor to store top k sequences; now they're just <start>
        seqs = k_prev_words  # (k, 1)

        # Tensor to store top k sequences' scores; now they're just 0
        top_k_scores = torch.zeros(k, 1).to(device)  # (k, 1)

        # Lists to store completed sequences and scores
        complete_seqs = list()
        complete_seqs_scores = list()

        # Start decoding
        step = 1
        h = decoder.init_hidden_state(encoder_out)

        # s is a number less than or equal to k, because sequences are removed from this process once they hit <end>
        while True:

            embeddings = decoder.embedding(k_prev_words).squeeze(1)  # (s, embed_dim)

            awe, _ = decoder.attention(encoder_out, h)  # (s, encoder_dim), (s, num_pixels)

            gate = decoder.sigmoid(decoder.f_beta(h))  # gating scalar, (s, encoder_dim)
            awe = gate * awe

            h = decoder.decode_step(torch.cat([embeddings, awe], dim=1), h)  # (s, decoder_dim)

            scores = decoder.fc(h)  # (s, vocab_size)
            scores = F.log_softmax(scores, dim=1)

            # Add
            scores = top_k_scores.expand_as(scores) + scores  # (s, vocab_size)

            # For the first step, all k points will have the same scores (since same k previous words, h, c)
            if step == 1:
                top_k_scores, top_k_words = scores[0].topk(k, 0, True, True)  # (s)
            else:
                # Unroll and find top scores, and their unrolled indices
                top_k_scores, top_k_words = scores.view(-1).topk(k, 0, True, True)  # (s)

            # Convert unrolled indices to actual indices of scores
            prev_word_inds = top_k_words // vocab_size  # (s)
            next_word_inds = top_k_words % vocab_size  # (s)

            # Add new words to sequences
            seqs = torch.cat([seqs[prev_word_inds], next_word_inds.unsqueeze(1)], dim=1)  # (s, step+1)

            # Which sequences are incomplete (didn't reach <end>)?
            incomplete_inds = [ind for ind, next_word in enumerate(next_word_inds) if
                               next_word != word_map['<end>']]
            complete_inds = list(set(range(len(next_word_inds))) - set(incomplete_inds))

            # Set aside complete sequences
            # print(complete_inds)
            if len(complete_inds) > 0:
                complete_seqs.extend(seqs[complete_inds].tolist())
                complete_seqs_scores.extend(top_k_scores[complete_inds])
            k -= len(complete_inds)  # reduce beam length accordingly

            # Proceed with incomplete sequences
            if k == 0:
                break
            seqs = seqs[incomplete_inds]
            h = h[prev_word_inds[incomplete_inds]]
            c = c[prev_word_inds[incomplete_inds]]
            encoder_out = encoder_out[prev_word_inds[incomplete_inds]]
            top_k_scores = top_k_scores[incomplete_inds].unsqueeze(1)
            k_prev_words = next_word_inds[incomplete_inds].unsqueeze(1)

            # Break if things have been going on too long
            if step > 50:
                break
            step += 1

        i = complete_seqs_scores.index(max(complete_seqs_scores))
        seq = complete_seqs[i]

        # References
        img_caps = allcaps[0].tolist()
        img_captions = list(
            map(lambda c: [w for w in c if w not in {word_map['<start>'], word_map['<end>'], word_map['<pad>']}],
                img_caps))  # remove <start> and pads
        references.append(img_captions)

        # Hypotheses
        hypotheses.append([w for w in seq if w not in {word_map['<start>'], word_map['<end>'], word_map['<pad>']}])

        assert len(references) == len(hypotheses)

    # Calculate BLEU-4 scores
    bleu4 = corpus_bleu(references, hypotheses)

    return bleu4


if __name__ == '__main__':
    beam_size = 3
    print("\nBLEU-4 score @ beam size of %d is %.4f." % (beam_size, evaluate(beam_size)))
